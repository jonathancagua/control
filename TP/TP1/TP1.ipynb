# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
SAMPLES = 200

muestra = pd.read_csv('daq_log.csv')
muestra
# Out:
#           No           Date      Time  ADC    DAC
# 0          1  26 March 2023  17:27:26   94  65535
# 1          2  26 March 2023  17:27:26  295  65535
# 2          3  26 March 2023  17:27:26  298  65535
# 3          4  26 March 2023  17:27:26  299  65535
# 4          5  26 March 2023  17:27:26  302  65535
# ...      ...            ...       ...  ...    ...
# 28960  28961  26 March 2023  17:28:08  271      0
# 28961  28962  26 March 2023  17:28:08  270      0
# 28962  28963  26 March 2023  17:28:08  272      0
# 28963  28964  26 March 2023  17:28:08  282  65535
# 28964  28965  26 March 2023  17:28:08  288  65535
#
# [28965 rows x 5 columns]

# %%
plt.figure(figsize=(24, 6))
plt.title('STEP response')
plt.plot(muestra['No'][:SAMPLES], muestra['ADC'][:SAMPLES], 'o', label='ADC')
plt.plot(muestra['No'][:SAMPLES], muestra['DAC'][:SAMPLES], 'o', label='DAC')
plt.ylabel('Magnitude')
plt.xlabel('Sample [No]')
plt.legend()
plt.grid()
