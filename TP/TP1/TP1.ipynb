# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
SAMPLES = 800

muestra = pd.read_csv('daq_log.csv')
muestra
# Out:
#           No           Date      Time   ADC   DAC
# 0          1  27 March 2023  21:20:39        1024
# 1          2  27 March 2023  21:20:39  246   1024
# 2          3  27 March 2023  21:20:39  307   1024
# 3          4  27 March 2023  21:20:39  364   1024
# 4          5  27 March 2023  21:20:39  416   1024
# ...      ...            ...       ...   ...   ...
# 20878  20879  27 March 2023  21:21:15  980   1024
# 20879  20880  27 March 2023  21:21:15  981   1024
# 20880  20881  27 March 2023  21:21:15  981   1024
# 20881  20882  27 March 2023  21:21:15  981   1024
# 20882  20883  27 March 2023  21:21:15  981   1024
#
# [20883 rows x 5 columns]

# %%
plt.figure(figsize=(24, 6))
plt.title('STEP response')
#plt.plot(muestra['No'][:SAMPLES], muestra['ADC'][:SAMPLES], 'o', label='ADC')
plt.plot(muestra['No'][:SAMPLES], muestra['DAC'][:SAMPLES], 'o', label='DAC')
plt.ylabel('Magnitude')
plt.xlabel('Sample [No]')
plt.legend()
plt.grid()
